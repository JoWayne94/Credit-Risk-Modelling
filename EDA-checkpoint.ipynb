# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from statsmodels.graphics.mosaicplot import mosaic

# %% [markdown]
# # Details

# %%
df = pd.read_csv(r'C:\Users\tjowayne\Downloads\UCI_Credit_Card\UCI_Credit_Card.csv')
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.describe(include='all')
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
test = df.groupby('AGE').size()
test.plot(title='test',xticks=(1,2,3,4,5,6))

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.nunique()
# Out:
# ID                            30000
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_0                            11
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22723
# BILL_AMT2                     22346
# BILL_AMT3                     22026
# BILL_AMT4                     21548
# BILL_AMT5                     21010
# BILL_AMT6                     20604
# PAY_AMT1                       7943
# PAY_AMT2                       7899
# PAY_AMT3                       7518
# PAY_AMT4                       6937
# PAY_AMT5                       6897
# PAY_AMT6                       6939
# default.payment.next.month        2
# dtype: int64

# %% [markdown]
# # Bar Plots

# %%
df['default.payment.next.month'].value_counts().plot.bar(title='Freq Dist of default payment next month')

# %%
df['SEX'].value_counts().plot.bar(title='Freq Dist of Sex')

# %%
df['MARRIAGE'].value_counts().plot.bar(title='Freq Dist of Marriage')

# %%
count,bin_edges = np.histogram(df['EDUCATION'])
df['EDUCATION'].plot(kind='hist', xticks=bin_edges)
plt.ylabel('Frequency of Education')
# Out:
# Text(0, 0.5, 'Frequency of Education')

# %%
count,bin_edges = np.histogram(df['PAY_0'])
df['PAY_0'].plot(kind='hist', xticks=bin_edges)
plt.ylabel('Frequency of Repayment Status Sep')
# Out:
# Text(0, 0.5, 'Frequency of Repayment Status Sep')

# %%
count,bin_edges = np.histogram(df['PAY_2'])
df['PAY_2'].plot(kind='hist', xticks=bin_edges)
plt.ylabel('Frequency of Repayment Status Aug')
# Out:
# Text(0, 0.5, 'Frequency of Repayment Status Aug')

# %%
new = df[['EDUCATION', 'LIMIT_BAL']].groupby(['EDUCATION'], as_index=False).mean()
new.plot.bar(x='EDUCATION', y='LIMIT_BAL')

# %% [markdown]
# # Fix Data Points

# %%
df.loc[:,'EDUCATION'].replace({0:4, 5:4, 6:4}, inplace=True)
df.loc[:,'MARRIAGE'].replace({0:3}, inplace=True)
df.loc[:,'PAY_0'].replace({-2:0, -1:0}, inplace=True)
df.loc[:,'PAY_2'].replace({-2:0, -1:0}, inplace=True)
df.loc[:,'PAY_3'].replace({-2:0, -1:0}, inplace=True)
df.loc[:,'PAY_4'].replace({-2:0, -1:0}, inplace=True)
df.loc[:,'PAY_5'].replace({-2:0, -1:0}, inplace=True)
df.loc[:,'PAY_6'].replace({-2:0, -1:0}, inplace=True)

# %%
df['MARRIAGE'].value_counts().plot.bar(title='Freq Dist of Marriage')

# %%
new = df[['EDUCATION', 'LIMIT_BAL']].groupby(['EDUCATION'], as_index=False).mean()
new.plot.bar(x='EDUCATION', y='LIMIT_BAL')

# %%
count,bin_edges = np.histogram(df['PAY_0'])
df['PAY_0'].plot(kind='hist', xticks=bin_edges)
plt.ylabel('Frequency of Repayment Status Sep')
# Out:
# Text(0, 0.5, 'Frequency of Repayment Status Sep')

# %%
temp_df = df[['EDUCATION','LIMIT_BAL']].groupby(['EDUCATION'])
stats.f_oneway(temp_df.get_group(int(1))['LIMIT_BAL'],temp_df.get_group(int(2))['LIMIT_BAL'])
# Out:
# F_onewayResult(statistic=1617.8106440277354, pvalue=0.0)

# %% [markdown]
# # Univariate Distribution

# %%
col_names = ['LIMIT_BAL','AGE', 'BILL_AMT1', 'BILL_AMT2', 'PAY_AMT1', 'PAY_AMT2']

fig, ax = plt.subplots(len(col_names), figsize=(16,12))

for i, col_val in enumerate(col_names):

    sns.distplot(df[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)
# Out:
# C:\Users\tjowayne\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Bivariate Distribution

# %%
df_temp = df.drop(['ID','SEX', 'EDUCATION', 'MARRIAGE', 'default.payment.next.month', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
                  , axis=1)
sns.pairplot(df_temp)
#plt.scatter(df['PAY_0'], df['BILL_AMT1'])

# %% [markdown]
# # Missing Value Analysis

# %%
df.isnull().values.any()
# Out:
# False

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# # Outlier Detection Analysis

# %%
col_names = ['LIMIT_BAL','AGE', 'PAY_0', 'BILL_AMT1', 'PAY_AMT1']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=df[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

# %%
sns.boxplot(x='EDUCATION', y='LIMIT_BAL', data=df)

# %% [markdown]
# # Percentile Based Outlier Removal

# %%
def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

col_names = ['LIMIT_BAL', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
             'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):
    x = df[col_val][:1000]
    sns.distplot(x, ax=ax[i], rug=True, hist=False)
    outliers = x[percentile_based_outlier(x)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
# Out:
# C:\Users\tjowayne\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
dict = {}
for i, col_val in enumerate(col_names):
    x = df[col_val]
    outliers = x[percentile_based_outlier(x)]
    dict["df_" + col_val] = outliers.index

# %%
for i in dict:
    df = df.loc[~df['ID'].isin(list(dict[i]))]

# %%
len(df)
# Out:
# 23733

# %% [markdown]
# # Pivot Table

# %%
df_temp = df[['AGE', 'EDUCATION', 'PAY_AMT1']]
df_group = df_temp.groupby(['AGE', 'EDUCATION'], as_index=False).mean()
df_pivot = df_group.pivot(index='EDUCATION', columns='AGE')
df_pivot
# Out:
#               PAY_AMT1                                                      \
# AGE                 21           22           23           24           25
# EDUCATION
# 1          1668.166667  2926.577320  3251.770925  4126.528736  4127.746177
# 2          1825.886364  2083.578231  3404.047511  3485.777164  5520.770642
# 3          1497.000000  1942.766667  2523.804348  3490.450980  3120.543210
# 4          1518.000000  1694.142857  2365.866667  1910.555556  3810.357143
#
#                                                                             \
# AGE                 26           27           28           29           30
# EDUCATION
# 1          4961.655172  5694.360075  7900.671785  6274.479475  7439.146392
# 2          4133.860606  4623.261450  5106.008230  5089.048544  5183.828740
# 3          4110.518182  4399.405660  4196.368421  4356.414141  7148.728972
# 4          9848.562500  4974.434783  4717.000000  4872.545455  4881.315789
#
# ...

# %% [markdown]
# # Correlation Matrix

# %%
f, ax = plt.subplots(figsize=(10, 8))
df_corr = df[['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3','default.payment.next.month']]
corr = df_corr.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True)

# %% [markdown]
# # Verify Results

# %%
sns.regplot(x='BILL_AMT4',y='BILL_AMT5',data=df)

# %%
sns.regplot(x='PAY_4',y='PAY_5',data=df)

# %%
mosaic(df, ['MARRIAGE', 'default.payment.next.month'])
plt.xlabel('PAY_0')
plt.ylabel('BILL_AMT1')

plt.show()

# %%
df.to_csv(r'C:\Users\tjowayne\Desktop\Model\credit_card.csv', index=False)
